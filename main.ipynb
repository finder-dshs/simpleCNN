# %% [markdown]
# <a href="https://colab.research.google.com/github/finder-dshs/simpleCNN/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu
# Out:
# ...
#      |████████████████████████████████| 394.3MB 42kB/s
# ...

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
print(len(x_train), len(y_train))
print(len(x_test), len(y_test))
# Out:
# 60000 60000
# 10000 10000

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4928 - accuracy: 0.8552
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1525 - accuracy: 0.9541
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1056 - accuracy: 0.9684
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0877 - accuracy: 0.9717
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0785 - accuracy: 0.9764
# 313/313 - 0s - loss: 0.0763 - accuracy: 0.9769
# [0.0763474851846695, 0.9768999814987183]

# %%
plt.imshow(x_test[122])

# %%
a = model.predict(np.reshape(x_test[122], (1, 28, 28)))

# %%
print('result:', list(a[0]).index(max(a[0])), 'accuracy:', round(float(max(a[0]))*100, 1))
# Out:
# result: 7 accuracy: 99.9
